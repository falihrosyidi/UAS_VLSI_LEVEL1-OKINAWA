# %%
def q8_24_to_decimal(hex_str):
    # 1. Konversi hex ke integer
    value = int(hex_str, 16)
    
    # 2. Tangani Signed Integer (Two's Complement)
    # Jika bit ke-31 adalah 1, maka ini bilangan negatif
    if value & (1 << 31):
        value -= (1 << 32)
    
    # 3. Bagi dengan 2^24 untuk mendapatkan nilai desimal
    decimal_value = value / (2**24)
    
    return decimal_value

# Contoh Penggunaan:
hex_input = "01400000" # Contoh: 1.25 dalam Q8.24
result = q8_24_to_decimal(hex_input)

print(f"Hex: {hex_input}")
print(f"Decimal: {result}")

# Contoh Angka Negatif
hex_neg = "FE800000" # Contoh: -1.5 dalam Q8.24
print(f"Hex Negatif: {hex_neg} -> Decimal: {q8_24_to_decimal(hex_neg)}")
# Out:
# Hex: 01400000
# Decimal: 1.25
# Hex Negatif: FE800000 -> Decimal: -1.5

# %%
circle_01=["00FA13C3","00FA5033","00FA089D","00FA64CD","FF0597D1","00FA8D02","00FA65C1","00FAB650", "00FAB650"]
print(f"INPUT: (0,1) cross")
for hex in circle_01:
    print(f"{q8_24_to_decimal(hex)}")
print()

circle_10 = ["00FA0691", "00FA3A1D", "00F9FD50", "00FA6BEB", "FF059235", "00FA98AE", "00FA4D5D", "00FAC8FB", "00FA7CA7"]
print(f"INPUT: (1,0) CIRCLE")
for hex in circle_10:
    print(f"{q8_24_to_decimal(hex)}")
print()

circle_disc = ["0079A651","0079A278"]    
print(f"DISCRIMINATOR OUTPUT CIRCLE")
for hex in circle_disc:
    print(f"{q8_24_to_decimal(hex)}")
print()
# Out:
# INPUT: (0,1) CIRCLE
# 0.9768640398979187
# 0.9777862429618835
# 0.9766939282417297
# 0.978100597858429
# -0.9781522154808044
# 0.978714108467102
# 0.9781151413917542
# 0.979344367980957
# 0.979344367980957
#
# INPUT: (1,0) CIRCLE
# 0.9766626954078674
# 0.9774492383003235
# 0.9765214920043945
# 0.9782091975212097
# -0.9782378077507019
# 0.9788922071456909
# 0.9777429699897766
# 0.9796292185783386
# 0.9784645438194275
#
# DISCRIMINATOR OUTPUT CIRCLE
# 0.4751940369606018
# 0.47513532638549805

# %%
cross_01 = ["FF05BB2E", "00FAC75F", "FF05AA0E", "00FAA41F", "00FA6D0A", "00FA8DF0", "FF05B968", "00FA5171", "FF0533C0"]
print(f"INPUT: (0,1) CROSS")
for hex in cross_01:
    print(f"{q8_24_to_decimal(hex)}")
print()

cross_10 = ["FF05AFFE", "00FAD3F0", "FF058AAC", "00FAA69A", "00FA8888", "00FA8BE2", "FF05A2C4", "00FA6233", "FF0525F1"]
print(f"INPUT: (1,0) CROSS")
for hex in cross_10:
    print(f"{q8_24_to_decimal(hex)}")
print()

cross_disc = ["00786BBB","00789CC8"]    
print(f"DISCRIMINATOR OUTPUT CROSS")
for hex in cross_disc:
    print(f"{q8_24_to_decimal(hex)}")
print()
# Out:
# INPUT: (0,1) CROSS
# -0.9776126146316528
# 0.9796046614646912
# -0.9778739213943481
# 0.979066789150238
# 0.9782263040542603
# 0.9787282943725586
# -0.9776396751403809
# 0.9778051972389221
# -0.9796791076660156
#
# INPUT: (1,0) CROSS
# -0.9777833223342896
# 0.9797964096069336
# -0.9783527851104736
# 0.9791046380996704
# 0.9786458015441895
# 0.9786969423294067
# -0.977985143661499
# 0.9780609011650085
# -0.9798898100852966
#
# DISCRIMINATOR OUTPUT CROSS
# 0.4703938364982605
# 0.4711422920227051
